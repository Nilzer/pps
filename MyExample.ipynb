# %% [markdown]
# ## Auftragsabrufe
#
# | Woche | Termin (KW)   | Produkt | Menge | Auftrag-ID |
# | ----- | ------------- | ------- | ----- | ---------- |
# | 1     | KW 46 (Tag 5) | P1      | 5     | A1         |
# | 1     | KW 46 (Tag 4) | P3      | 3     | A2         |
# | 2     | KW 47 (Tag 3) | P2      | 4     | A3         |
# | 3     | KW 48 (Tag 2) | P4      | 2     | A4         |
# | 4     | KW 49 (Tag 4) | P5      | 3     | A5         |
# | 4     | KW 49 (Tag 3) | P1      | 4     | A6         |

# %% [markdown]
# ## Schweißbaugruppen Übersicht
#
# | Produkt-ID | Produktname  | Beschreibung                 |
# | ---------- | ------------ | ---------------------------- |
# | P1         | Rahmen       | Geschweißter Grundrahmen     |
# | P2         | Halterung    | Geschweißte Konsole          |
# | P3         | Achsaufnahme | geschweißtes Verbindungsteil |
# | P4         | Träger       | geschweißter Längsträger     |
# | P5         | Gehäuse      | geschweißte Strukturbox      |

# %% [markdown]
# ## Arbeitsplan Baugruppen
#
# | Produkt | Stufe               | Maschine/Arbeitsplatz | Vorgang        | Dauer (h/Stück) | Rüstzeit (h) |
# | ------- | ------------------- | --------------------- | -------------- | --------------- | ------------ |
# | P1      | Roboter             | M11_Rob1              | Roboter      | 1.0             | 0.5          |
# | P1      | Schweißerei         | M9_Schweißen          | MAG-Schweißen  | 2.5             | 0.75         |
# | P2      | Roboter             | M11_Rob1              | Roboter | 0.8             | 0.5          |
# | P2      | Schweißerei         | M10_Schweißen         | WIG-Schweißen  | 2.0             | 0.75         |
# | P3      | Roboter             | M12_Rob2              | Roboter        | 1.2             | 0.5          |
# | P3      | Schweißerei         | M9_Schweißen          | MAG-Schweißen  | 1.8             | 0.75         |
# | P4      | Roboter             | M12_Rob2              | Roboterschweißen         | 1.0             | 0.5          |
# | P4      | Schweißerei         | M10_Schweißen         | WIG-Schweißen  | 2.2             | 0.75         |
# | P5      | Roboter             | M12_Rob2              | Roboterschweißen | 1.5             | 0.5          |
# | P5      | Schweißerei         | M10_Schweißen         | WIG-Schweißen  | 2.8             | 0.75         |

# %% [markdown]
# ## Stücklisten
#
# | Produkt         | Baugruppe                       | Einzelteile                  | Menge je Baugruppe |
# | --------------- | ------------------------------- | ---------------------------- | ------------------ |
# | P1 Rahmen       | Rohr A, Rohr B, Platte C        | A: 2 Stk, B: 1 Stk, C: 1 Stk |                    |
# | P2 Halterung    | Blech D, Lasche E               | D: 1 Stk, E: 2 Stk           |                    |
# | P3 Achsaufnahme | Platte F, Bolzen G              | F: 2 Stk, G: 2 Stk           |                    |
# | P4 Träger       | Rohr H, Flansch I, Platte J     | H: 1 Stk, I: 2 Stk, J: 1 Stk |                    |
# | P5 Gehäuse      | Wand K, Deckel L, Verstärkung M | K: 2 Stk, L: 1 Stk, M: 2 Stk |                    |

# %% [markdown]
# ### P1
#
# | Einzelteil | Vorgang        | Maschine        | Dauer (h/Stk) | Rüstzeit (h) | Nächster Vorgang |
# | ---------- | -------------- | --------------- | ------------- | ------------ | ---------------- |
# | Rohr A     | Zuschnitt      | M1_Säge         | 0.3           | 0.25         | Entgraten        |
# | Rohr A     | Entgraten      | M2_Schleifer    | 0.2           | 0.1          | –                |
# | Rohr B     | Zuschnitt      | M1_Säge         | 0.4           | 0.25         | Entgraten        |
# | Rohr B     | Entgraten      | M2_Schleifer    | 0.25          | 0.1          | –                |
# | Platte C   | Brennschneiden | M3_Brenner      | 0.5           | 0.3          | Bohren           |
# | Platte C   | Bohren         | M4_Bohrmaschine | 0.4           | 0.2          | –                |

# %% [markdown]
# ### P2
#
# | Einzelteil | Vorgang        | Maschine        | Dauer (h/Stk) | Rüstzeit (h) | Nächster Vorgang |
# | ---------- | -------------- | --------------- | ------------- | ------------ | ---------------- |
# | Blech D    | Laserschneiden | M5_Laser        | 0.6           | 0.4          | Kanten           |
# | Blech D    | Kanten         | M6_Abkantpresse | 0.5           | 0.3          | –                |
# | Lasche E   | Laserschneiden | M5_Laser        | 0.4           | 0.4          | Bohren           |
# | Lasche E   | Bohren         | M4_Bohrmaschine | 0.3           | 0.2          | –                |

# %% [markdown]
# ### P3
#
# | Einzelteil | Vorgang   | Maschine        | Dauer (h/Stk) | Rüstzeit (h) | Nächster Vorgang |
# | ---------- | --------- | --------------- | ------------- | ------------ | ---------------- |
# | Platte F   | Zuschnitt | M1_Säge         | 0.4           | 0.25         | Bohren           |
# | Platte F   | Bohren    | M4_Bohrmaschine | 0.3           | 0.2          | –                |
# | Bolzen G   | Drehen    | M7_Drehmaschine | 0.6           | 0.3          | Fräsen           |
# | Bolzen G   | Fräsen    | M8_Fräse        | 0.4           | 0.25         | –                |

# %% [markdown]
# ### P4
#
# | Einzelteil | Vorgang        | Maschine        | Dauer (h/Stk) | Rüstzeit (h) | Nächster Vorgang |
# | ---------- | -------------- | --------------- | ------------- | ------------ | ---------------- |
# | Rohr H     | Sägen          | M1_Säge         | 0.5           | 0.25         | Bohren           |
# | Rohr H     | Bohren         | M4_Bohrmaschine | 0.4           | 0.2          | –                |
# | Flansch I  | Brennschneiden | M3_Brenner      | 0.5           | 0.3          | Bohren           |
# | Flansch I  | Bohren         | M4_Bohrmaschine | 0.3           | 0.2          | –                |
# | Platte J   | Laserschneiden | M5_Laser        | 0.7           | 0.4          | Entgraten        |
# | Platte J   | Entgraten      | M2_Schleifer    | 0.2           | 0.1          | –                |

# %% [markdown]
# ### P5
#
# | Einzelteil    | Vorgang        | Maschine        | Dauer (h/Stk) | Rüstzeit (h) | Nächster Vorgang |
# | ------------- | -------------- | --------------- | ------------- | ------------ | ---------------- |
# | Wand K        | Blechzuschnitt | M5_Laser        | 0.8           | 0.4          | Kanten           |
# | Wand K        | Kanten         | M6_Abkantpresse | 0.6           | 0.3          | –                |
# | Deckel L      | Zuschnitt      | M1_Säge         | 0.4           | 0.25         | Bohren           |
# | Deckel L      | Bohren         | M4_Bohrmaschine | 0.3           | 0.2          | –                |
# | Verstärkung M | Drehen         | M7_Drehmaschine | 0.7           | 0.3          | Fräsen           |
# | Verstärkung M | Fräsen         | M8_Fräse        | 0.5           | 0.25         | –                |

# %% [markdown]
# | Maschine        | Beschreibung                    | Typische Einzelteile |
# | --------------- | ------------------------------- | -------------------- |
# | M1_Säge         | Sägen / Zuschnitt               | Rohr A, B, F, H, L   |
# | M2_Schleifer    | Entgraten, Schleifen            | Rohr A, B, J         |
# | M3_Brenner      | Brennschneiden                  | C, I                 |
# | M4_Bohrmaschine | Bohren                          | C, E, F, H, I, L     |
# | M5_Laser        | Laserschneiden / Blechzuschnitt | D, E, J, K           |
# | M6_Abkantpresse | Kanten                          | D, K                 |
# | M7_Drehmaschine | Drehen                          | G, M                 |
# | M8_Fräse        | Fräsen                          | G, M                 |

# %% [markdown]
# | Einzelteil    | Menge pro Baugruppe | Baugruppen-Verwendung |
# | ------------- | ------------------- | --------------------- |
# | Rohr A        | 2                   | Rahmen (P1)           |
# | Rohr B        | 1                   | Rahmen (P1)           |
# | Platte C      | 1                   | Rahmen (P1)           |
# | Blech D       | 1                   | Halterung (P2)        |
# | Lasche E      | 2                   | Halterung (P2)        |
# | Platte F      | 2                   | Achsaufnahme (P3)     |
# | Bolzen G      | 2                   | Achsaufnahme (P3)     |
# | Rohr H        | 1                   | Träger (P4)           |
# | Flansch I     | 2                   | Träger (P4)           |
# | Platte J      | 1                   | Träger (P4)           |
# | Wand K        | 2                   | Gehäuse (P5)          |
# | Deckel L      | 1                   | Gehäuse (P5)          |
# | Verstärkung M | 2                   | Gehäuse (P5)          |
